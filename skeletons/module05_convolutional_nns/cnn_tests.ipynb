# %% [markdown]
# # Convolutional Neural Networks for Image Recognition
# ## Advanced Machine Learning

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import os
import fnmatch
import matplotlib.pyplot as plt

from tensorflow import keras
from tensorflow.keras.layers import InputLayer
from tensorflow.keras.layers import Convolution2D, Dense, MaxPooling2D, Flatten, BatchNormalization, Dropout
from tensorflow.keras import Sequential
import random
import re

# pip install pypng
import png
import sklearn.metrics

# Provided 
from core50 import *

##################
# Configure figure parameters

FONTSIZE = 18
FIGURE_SIZE = (10,4)
FIGURE_SIZE2 = (10,10)

plt.rcParams.update({'font.size': FONTSIZE})
plt.rcParams['figure.figsize'] = FIGURE_SIZE
# Default tick label size
plt.rcParams['xtick.labelsize'] = FONTSIZE
plt.rcParams['ytick.labelsize'] = FONTSIZE

## TURN OFF GPU
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# %%
# Load up a single image & view it
directory = '/home/fagg/datasets/core50/core50_128x128/s1/o21'
files = os.listdir(directory)

r = png.Reader(directory + "/" + files[0])
it = r.read()
image_2d = np.vstack(map(np.uint8, it[2]))
image_3d = np.reshape(image_2d,
                         (128,128,3))

plt.imshow(image_3d)
# Out:
# /tmp/ipykernel_1150692/3985610497.py:7: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   image_2d = np.vstack(map(np.uint8, it[2]))

# %% [markdown]
# ## Load Data Sets

# %%
## File location
directory_base = '/home/fagg/datasets/core50/core50_128x128'

# Training set: define which files to load for each object
#val = '.*[05].png'
val_files = '.*[0].png'

### Positive cases
# Define which objects to load
#object_list = ['o25', 'o22', 'o23', 'o24']
object_list = ['o21']

# Define which conditions to load
#condition_list = ['s1', 's2', 's3', 's4', 's5', 's7', 's8', 's9', 's10', 's11']
#condition_list = ['s1', 's2', 's3', 's4']
condition_list = ['s1']

# Load all of the objects/condition
ins_pos = load_multiple_image_sets_from_directories(directory_base, condition_list, object_list, val_files)

### Negative cases
# Define which objects to load
#object_list2 = ['o45', 'o42', 'o43', 'o44']
object_list2 = ['o41']
ins_neg = load_multiple_image_sets_from_directories(directory_base, condition_list, object_list2, val_files)

### Combine positives and negatives into a common data set
outs_pos = np.append(np.ones((ins_pos.shape[0],1)), np.zeros((ins_pos.shape[0],1)), axis=1)
outs_neg = np.append(np.zeros((ins_pos.shape[0],1)), np.ones((ins_pos.shape[0],1)), axis=1)

ins = np.append(ins_pos, ins_neg, axis=0)
outs = np.append(outs_pos, outs_neg, axis=0)

########################################################################
# Validation set
# Define which files to load for each object
val_files = '.*[5].png'

### Positives
# Define which objects to load
object_list = ['o21']
#object_list = ['o21']

# Load the positives
ins_pos_validation = load_multiple_image_sets_from_directories(directory_base, condition_list, object_list, val_files)

### Negatives
# Define objects
object_list2 = ['o41']
#object_list2 = ['o41']

# Load the negative cases
ins_neg_validation = load_multiple_image_sets_from_directories(directory_base, condition_list, object_list2, val_files)

### Combine positives and negatives
outs_pos_validation = np.append(np.ones((ins_pos_validation.shape[0], 1)), np.zeros((ins_pos_validation.shape[0], 1)), axis=1)
outs_neg_validation = np.append(np.zeros((ins_pos_validation.shape[0], 1)), np.ones((ins_pos_validation.shape[0], 1)), axis=1)

ins_validation = np.append(ins_pos_validation, ins_neg_validation, axis=0)
outs_validation = np.append(outs_pos_validation, outs_neg_validation, axis=0)
# Out:
# ##################
# /home/fagg/datasets/core50/core50_128x128/s1/o21 .*[0].png
# ##################
# /home/fagg/datasets/core50/core50_128x128/s1/o41 .*[0].png
# ##################
# /home/fagg/datasets/core50/core50_128x128/s1/o21 .*[5].png
# ##################
# /home/fagg/datasets/core50/core50_128x128/s1/o41 .*[5].png

# %%
ins.shape
# Out:
# (60, 128, 128, 3)

# %%
outs.shape
# Out:
# (60, 2)

# %%
ins_validation.shape
# Out:
# (60, 128, 128, 3)

# %%
outs_validation.shape
# Out:
# (60, 2)

# %% [markdown]
# ## Create Network

# %%
def create_classifier_network(image_size, nchannels, n_classes, lambda_l2=None, p_dropout=0.5):
    if lambda_l2 is not None:
        lambda_l2 = tf.keras.regularizers.l2(lambda_l2)
    model = Sequential()
    model.add(InputLayer(input_shape=(image_size[0], image_size[1], nchannels)))
    model.add(Convolution2D(filters=10,
                           kernel_size=(5,5),
                           strides=1,
                           padding='valid',
                           use_bias=True,
                           kernel_initializer='random_uniform',
                            bias_initializer='zeros',
                           name='C1',
                            activation='elu',
                           kernel_regularizer=lambda_l2))
    model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))
    
    model.add(Flatten())
    model.add(Dense(units=100,
                   activation='elu',
                   use_bias=True,
                   kernel_initializer='truncated_normal',
                   bias_initializer='zeros',
                   name='D1',
                   kernel_regularizer=lambda_l2))
    
    model.add(Dropout(p_dropout))
    
    model.add(Dense(units=n_classes,
                   activation='softmax',
                   use_bias=True,
                   kernel_initializer='truncated_normal',
                   bias_initializer='zeros',
                   name='output',
                   kernel_regularizer=lambda_l2))
    
     # The optimizer determines how the gradient descent is to be done
    opt = tf.keras.optimizers.Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, 
                            epsilon=None, decay=0.0, amsgrad=False)
    
    model.compile(loss='categorical_crossentropy', optimizer=opt, 
                  metrics=['accuracy'])
    print(model.summary())
    
    return model

# %%
model = create_classifier_network((ins.shape[1], ins.shape[2]), ins.shape[3], 2)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# C1 (Conv2D)                  (None, 124, 124, 10)      760
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 62, 62, 10)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 38440)             0
# _________________________________________________________________
# D1 (Dense)                   (None, 100)               3844100
# _________________________________________________________________
# dropout (Dropout)            (None, 100)               0
# _________________________________________________________________
# output (Dense)               (None, 2)                 202
# =================================================================
# Total params: 3,845,062
# Trainable params: 3,845,062
# Non-trainable params: 0
# _________________________________________________________________
# None
# 2022-02-24 14:52:27.534788: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-02-24 14:52:27.534825: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: fenrir
# 2022-02-24 14:52:27.534833: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: fenrir
# 2022-02-24 14:52:27.534932: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 510.47.3
# 2022-02-24 14:52:27.534958: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 510.47.3
# 2022-02-24 14:52:27.534966: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 510.47.3
# 2022-02-24 14:52:27.535224: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /home/fagg/miniconda3/envs/tf/lib/python3.9/site-packages/keras/optimizer_v2/optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(

# %%
# Callbacks
early_stopping_cb = keras.callbacks.EarlyStopping(patience=10,
                                                  restore_best_weights=True,
                                                      min_delta=0.01)

# %%
history = model.fit(x=ins, y=outs, epochs=100, verbose=1,
                        validation_data=(ins_validation, outs_validation), 
                        callbacks=[early_stopping_cb])
# Out:
# 2022-02-24 14:52:31.452917: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100
# 2/2 [==============================] - 1s 241ms/step - loss: 0.6811 - accuracy: 0.6333 - val_loss: 0.7105 - val_accuracy: 0.5000
# Epoch 2/100
# 2/2 [==============================] - 0s 123ms/step - loss: 0.7090 - accuracy: 0.5500 - val_loss: 0.5783 - val_accuracy: 0.8333
# Epoch 3/100
# 2/2 [==============================] - 0s 117ms/step - loss: 0.6652 - accuracy: 0.6500 - val_loss: 0.6132 - val_accuracy: 0.5167
# Epoch 4/100
# 2/2 [==============================] - 0s 130ms/step - loss: 0.5862 - accuracy: 0.7167 - val_loss: 0.5487 - val_accuracy: 0.7333
# Epoch 5/100
# 2/2 [==============================] - 0s 130ms/step - loss: 0.6009 - accuracy: 0.6167 - val_loss: 0.5151 - val_accuracy: 0.8500
# Epoch 6/100
# 2/2 [==============================] - 0s 115ms/step - loss: 0.5896 - accuracy: 0.6833 - val_loss: 0.5055 - val_accuracy: 0.8333
# Epoch 7/100
# 2/2 [==============================] - 0s 119ms/step - loss: 0.5251 - accuracy: 0.7667 - val_loss: 0.4729 - val_accuracy: 0.8667
# Epoch 8/100
# 2/2 [==============================] - 0s 118ms/step - loss: 0.4478 - accuracy: 0.8333 - val_loss: 0.4585 - val_accuracy: 0.8833
# Epoch 9/100
# 2/2 [==============================] - 0s 127ms/step - loss: 0.4213 - accuracy: 0.8833 - val_loss: 0.4342 - val_accuracy: 0.8833
# Epoch 10/100
# 2/2 [==============================] - 0s 118ms/step - loss: 0.4251 - accuracy: 0.9333 - val_loss: 0.4246 - val_accuracy: 0.8833
# Epoch 11/100
# 2/2 [==============================] - 0s 113ms/step - loss: 0.4492 - accuracy: 0.8833 - val_loss: 0.3987 - val_accuracy: 0.8833
# Epoch 12/100
# 2/2 [==============================] - 0s 121ms/step - loss: 0.4444 - accuracy: 0.8500 - val_loss: 0.3776 - val_accuracy: 0.9000
# Epoch 13/100
# 2/2 [==============================] - 0s 127ms/step - loss: 0.3909 - accuracy: 0.8667 - val_loss: 0.3618 - val_accuracy: 0.9167
# Epoch 14/100
# 2/2 [==============================] - 0s 126ms/step - loss: 0.3517 - accuracy: 0.8667 - val_loss: 0.3545 - val_accuracy: 0.9000
# Epoch 15/100
# 2/2 [==============================] - 0s 123ms/step - loss: 0.3285 - accuracy: 0.8833 - val_loss: 0.3337 - val_accuracy: 0.9167
# Epoch 16/100
# 2/2 [==============================] - 0s 124ms/step - loss: 0.2571 - accuracy: 0.9667 - val_loss: 0.3213 - val_accuracy: 0.9167
# Epoch 17/100
# 2/2 [==============================] - 0s 125ms/step - loss: 0.3392 - accuracy: 0.8833 - val_loss: 0.3090 - val_accuracy: 0.9000
# Epoch 18/100
# 2/2 [==============================] - 0s 128ms/step - loss: 0.3153 - accuracy: 0.9333 - val_loss: 0.2955 - val_accuracy: 0.9167
# Epoch 19/100
# 2/2 [==============================] - 0s 121ms/step - loss: 0.2653 - accuracy: 0.9167 - val_loss: 0.2949 - val_accuracy: 0.9167
# Epoch 20/100
# 2/2 [==============================] - 0s 120ms/step - loss: 0.2604 - accuracy: 0.9333 - val_loss: 0.2831 - val_accuracy: 0.9333
# Epoch 21/100
# 2/2 [==============================] - 0s 111ms/step - loss: 0.2701 - accuracy: 0.9333 - val_loss: 0.2661 - val_accuracy: 0.9000
# Epoch 22/100
# 2/2 [==============================] - 0s 120ms/step - loss: 0.2963 - accuracy: 0.8833 - val_loss: 0.2602 - val_accuracy: 0.9000
# Epoch 23/100
# 2/2 [==============================] - 0s 118ms/step - loss: 0.2817 - accuracy: 0.9333 - val_loss: 0.2597 - val_accuracy: 0.9333
# Epoch 24/100
# 2/2 [==============================] - 0s 126ms/step - loss: 0.2141 - accuracy: 0.9500 - val_loss: 0.2501 - val_accuracy: 0.9333
# Epoch 25/100
# 2/2 [==============================] - 0s 110ms/step - loss: 0.2363 - accuracy: 0.9500 - val_loss: 0.2363 - val_accuracy: 0.9167
# Epoch 26/100
# 2/2 [==============================] - 0s 121ms/step - loss: 0.2202 - accuracy: 0.9333 - val_loss: 0.2517 - val_accuracy: 0.9000
# Epoch 27/100
# 2/2 [==============================] - 0s 118ms/step - loss: 0.1952 - accuracy: 0.9500 - val_loss: 0.2284 - val_accuracy: 0.9000
# Epoch 28/100
# 2/2 [==============================] - 0s 120ms/step - loss: 0.2191 - accuracy: 0.9167 - val_loss: 0.2264 - val_accuracy: 0.9333
# Epoch 29/100
# 2/2 [==============================] - 0s 129ms/step - loss: 0.1948 - accuracy: 0.9333 - val_loss: 0.2581 - val_accuracy: 0.9167
# Epoch 30/100
# 2/2 [==============================] - 0s 123ms/step - loss: 0.2292 - accuracy: 0.9333 - val_loss: 0.2111 - val_accuracy: 0.9500
# Epoch 31/100
# 2/2 [==============================] - 0s 124ms/step - loss: 0.2113 - accuracy: 0.9667 - val_loss: 0.2280 - val_accuracy: 0.9000
# Epoch 32/100
# 2/2 [==============================] - 0s 131ms/step - loss: 0.1811 - accuracy: 0.9667 - val_loss: 0.2071 - val_accuracy: 0.9000
# Epoch 33/100
# 2/2 [==============================] - 0s 130ms/step - loss: 0.1613 - accuracy: 0.9500 - val_loss: 0.1960 - val_accuracy: 0.9500
# Epoch 34/100
# 2/2 [==============================] - 0s 136ms/step - loss: 0.1562 - accuracy: 0.9667 - val_loss: 0.2070 - val_accuracy: 0.9333
# Epoch 35/100
# 2/2 [==============================] - 0s 120ms/step - loss: 0.1508 - accuracy: 0.9667 - val_loss: 0.1939 - val_accuracy: 0.9500
# Epoch 36/100
# 2/2 [==============================] - 0s 128ms/step - loss: 0.1815 - accuracy: 0.9667 - val_loss: 0.1807 - val_accuracy: 0.9500
# Epoch 37/100
# 2/2 [==============================] - 0s 116ms/step - loss: 0.1589 - accuracy: 0.9500 - val_loss: 0.1811 - val_accuracy: 0.9000
# Epoch 38/100
# 2/2 [==============================] - 0s 128ms/step - loss: 0.1307 - accuracy: 0.9667 - val_loss: 0.1722 - val_accuracy: 0.9667
# Epoch 39/100
# 2/2 [==============================] - 0s 127ms/step - loss: 0.1505 - accuracy: 0.9667 - val_loss: 0.1718 - val_accuracy: 0.9500
# Epoch 40/100
# 2/2 [==============================] - 0s 120ms/step - loss: 0.1522 - accuracy: 0.9500 - val_loss: 0.1654 - val_accuracy: 0.9500
# Epoch 41/100
# 2/2 [==============================] - 0s 113ms/step - loss: 0.1220 - accuracy: 0.9667 - val_loss: 0.1629 - val_accuracy: 0.9500
# Epoch 42/100
# 2/2 [==============================] - 0s 120ms/step - loss: 0.1503 - accuracy: 0.9667 - val_loss: 0.1589 - val_accuracy: 0.9667
# Epoch 43/100
# 2/2 [==============================] - 0s 129ms/step - loss: 0.1563 - accuracy: 0.9500 - val_loss: 0.1552 - val_accuracy: 0.9667
# Epoch 44/100
# 2/2 [==============================] - 0s 126ms/step - loss: 0.1125 - accuracy: 1.0000 - val_loss: 0.1550 - val_accuracy: 0.9500
# Epoch 45/100
# 2/2 [==============================] - 0s 115ms/step - loss: 0.1071 - accuracy: 0.9667 - val_loss: 0.1476 - val_accuracy: 0.9500
# Epoch 46/100
# 2/2 [==============================] - 0s 127ms/step - loss: 0.1429 - accuracy: 0.9500 - val_loss: 0.1424 - val_accuracy: 0.9667
# Epoch 47/100
# 2/2 [==============================] - 0s 114ms/step - loss: 0.0990 - accuracy: 0.9833 - val_loss: 0.1397 - val_accuracy: 0.9667
# Epoch 48/100
# 2/2 [==============================] - 0s 130ms/step - loss: 0.1185 - accuracy: 0.9667 - val_loss: 0.1349 - val_accuracy: 0.9667
# Epoch 49/100
# 2/2 [==============================] - 0s 127ms/step - loss: 0.0916 - accuracy: 0.9833 - val_loss: 0.1328 - val_accuracy: 0.9500
# Epoch 50/100
# 2/2 [==============================] - 0s 118ms/step - loss: 0.1131 - accuracy: 0.9667 - val_loss: 0.1413 - val_accuracy: 0.9500
# Epoch 51/100
# 2/2 [==============================] - 0s 115ms/step - loss: 0.0926 - accuracy: 0.9667 - val_loss: 0.1298 - val_accuracy: 0.9500
# Epoch 52/100
# 2/2 [==============================] - 0s 120ms/step - loss: 0.0987 - accuracy: 0.9833 - val_loss: 0.1251 - val_accuracy: 0.9667
# Epoch 53/100
# 2/2 [==============================] - 0s 129ms/step - loss: 0.1007 - accuracy: 0.9833 - val_loss: 0.1235 - val_accuracy: 0.9667
# Epoch 54/100
# 2/2 [==============================] - 0s 126ms/step - loss: 0.0952 - accuracy: 0.9833 - val_loss: 0.1202 - val_accuracy: 0.9500
# Epoch 55/100
# 2/2 [==============================] - 0s 117ms/step - loss: 0.0911 - accuracy: 0.9667 - val_loss: 0.1255 - val_accuracy: 0.9500
# Epoch 56/100
# 2/2 [==============================] - 0s 114ms/step - loss: 0.1052 - accuracy: 0.9667 - val_loss: 0.1208 - val_accuracy: 0.9500
# Epoch 57/100
# 2/2 [==============================] - 0s 127ms/step - loss: 0.0759 - accuracy: 0.9833 - val_loss: 0.1113 - val_accuracy: 0.9667
# Epoch 58/100
# 2/2 [==============================] - 0s 137ms/step - loss: 0.0516 - accuracy: 1.0000 - val_loss: 0.1131 - val_accuracy: 1.0000
# Epoch 59/100
# 2/2 [==============================] - 0s 124ms/step - loss: 0.0819 - accuracy: 0.9667 - val_loss: 0.1070 - val_accuracy: 0.9833
# Epoch 60/100
# 2/2 [==============================] - 0s 121ms/step - loss: 0.0621 - accuracy: 1.0000 - val_loss: 0.1094 - val_accuracy: 0.9500
# Epoch 61/100
# 2/2 [==============================] - 0s 118ms/step - loss: 0.0732 - accuracy: 0.9833 - val_loss: 0.1090 - val_accuracy: 0.9500
# Epoch 62/100
# 2/2 [==============================] - 0s 114ms/step - loss: 0.0819 - accuracy: 1.0000 - val_loss: 0.1016 - val_accuracy: 0.9833
# Epoch 63/100
# 2/2 [==============================] - 0s 134ms/step - loss: 0.0754 - accuracy: 0.9667 - val_loss: 0.1012 - val_accuracy: 1.0000
# Epoch 64/100
# 2/2 [==============================] - 0s 122ms/step - loss: 0.0695 - accuracy: 1.0000 - val_loss: 0.1002 - val_accuracy: 0.9500
# Epoch 65/100
# 2/2 [==============================] - 0s 119ms/step - loss: 0.0587 - accuracy: 1.0000 - val_loss: 0.0998 - val_accuracy: 0.9500
# Epoch 66/100
# 2/2 [==============================] - 0s 117ms/step - loss: 0.0744 - accuracy: 0.9833 - val_loss: 0.0956 - val_accuracy: 1.0000
# Epoch 67/100
# 2/2 [==============================] - 0s 117ms/step - loss: 0.0829 - accuracy: 0.9833 - val_loss: 0.0927 - val_accuracy: 1.0000
# Epoch 68/100
# 2/2 [==============================] - 0s 131ms/step - loss: 0.0578 - accuracy: 1.0000 - val_loss: 0.1011 - val_accuracy: 0.9500
# Epoch 69/100
# 2/2 [==============================] - 0s 129ms/step - loss: 0.0574 - accuracy: 0.9833 - val_loss: 0.0938 - val_accuracy: 0.9500
# Epoch 70/100
# 2/2 [==============================] - 0s 115ms/step - loss: 0.0448 - accuracy: 1.0000 - val_loss: 0.0873 - val_accuracy: 1.0000
# Epoch 71/100
# 2/2 [==============================] - 0s 117ms/step - loss: 0.0732 - accuracy: 0.9833 - val_loss: 0.0864 - val_accuracy: 1.0000
# Epoch 72/100
# 2/2 [==============================] - 0s 116ms/step - loss: 0.0502 - accuracy: 1.0000 - val_loss: 0.1035 - val_accuracy: 0.9500
# Epoch 73/100
# 2/2 [==============================] - 0s 239ms/step - loss: 0.0553 - accuracy: 1.0000 - val_loss: 0.1048 - val_accuracy: 0.9500
# Epoch 74/100
# 2/2 [==============================] - 0s 190ms/step - loss: 0.0444 - accuracy: 1.0000 - val_loss: 0.0860 - val_accuracy: 0.9833
# Epoch 75/100
# 2/2 [==============================] - 0s 139ms/step - loss: 0.0411 - accuracy: 1.0000 - val_loss: 0.0802 - val_accuracy: 1.0000
# Epoch 76/100
# 2/2 [==============================] - 0s 177ms/step - loss: 0.0479 - accuracy: 1.0000 - val_loss: 0.0793 - val_accuracy: 1.0000
# Epoch 77/100
# 2/2 [==============================] - 0s 126ms/step - loss: 0.0500 - accuracy: 1.0000 - val_loss: 0.0887 - val_accuracy: 0.9500
# Epoch 78/100
# 2/2 [==============================] - 0s 120ms/step - loss: 0.0578 - accuracy: 0.9833 - val_loss: 0.0928 - val_accuracy: 0.9500
# Epoch 79/100
# 2/2 [==============================] - 0s 122ms/step - loss: 0.0346 - accuracy: 1.0000 - val_loss: 0.0772 - val_accuracy: 1.0000
# Epoch 80/100
# 2/2 [==============================] - 0s 120ms/step - loss: 0.0493 - accuracy: 0.9833 - val_loss: 0.0740 - val_accuracy: 1.0000
# Epoch 81/100
# 2/2 [==============================] - 0s 120ms/step - loss: 0.0466 - accuracy: 1.0000 - val_loss: 0.0750 - val_accuracy: 1.0000
# Epoch 82/100
# 2/2 [==============================] - 0s 137ms/step - loss: 0.0366 - accuracy: 1.0000 - val_loss: 0.0778 - val_accuracy: 0.9833
# Epoch 83/100
# 2/2 [==============================] - 0s 117ms/step - loss: 0.0400 - accuracy: 0.9833 - val_loss: 0.0757 - val_accuracy: 0.9833
# Epoch 84/100
# 2/2 [==============================] - 0s 117ms/step - loss: 0.0376 - accuracy: 1.0000 - val_loss: 0.0719 - val_accuracy: 0.9833
# Epoch 85/100
# 2/2 [==============================] - 0s 117ms/step - loss: 0.0330 - accuracy: 1.0000 - val_loss: 0.0766 - val_accuracy: 0.9833
# Epoch 86/100
# 2/2 [==============================] - 0s 123ms/step - loss: 0.0346 - accuracy: 1.0000 - val_loss: 0.0730 - val_accuracy: 0.9833
# Epoch 87/100
# 2/2 [==============================] - 0s 125ms/step - loss: 0.0232 - accuracy: 1.0000 - val_loss: 0.0704 - val_accuracy: 0.9833
# Epoch 88/100
# 2/2 [==============================] - 0s 128ms/step - loss: 0.0347 - accuracy: 1.0000 - val_loss: 0.0674 - val_accuracy: 1.0000
# Epoch 89/100
# 2/2 [==============================] - 0s 118ms/step - loss: 0.0332 - accuracy: 1.0000 - val_loss: 0.0650 - val_accuracy: 1.0000
# Epoch 90/100
# 2/2 [==============================] - 0s 115ms/step - loss: 0.0430 - accuracy: 1.0000 - val_loss: 0.0653 - val_accuracy: 1.0000
# Epoch 91/100
# 2/2 [==============================] - 0s 141ms/step - loss: 0.0281 - accuracy: 1.0000 - val_loss: 0.0750 - val_accuracy: 0.9667
# Epoch 92/100
# 2/2 [==============================] - 0s 128ms/step - loss: 0.0234 - accuracy: 1.0000 - val_loss: 0.0830 - val_accuracy: 0.9500
# Epoch 93/100
# 2/2 [==============================] - 0s 125ms/step - loss: 0.0243 - accuracy: 1.0000 - val_loss: 0.0829 - val_accuracy: 0.9500
# Epoch 94/100
# 2/2 [==============================] - 0s 136ms/step - loss: 0.0475 - accuracy: 0.9833 - val_loss: 0.0622 - val_accuracy: 0.9833
# Epoch 95/100
# 2/2 [==============================] - 0s 114ms/step - loss: 0.0361 - accuracy: 1.0000 - val_loss: 0.0693 - val_accuracy: 1.0000
# Epoch 96/100
# 2/2 [==============================] - 0s 125ms/step - loss: 0.0313 - accuracy: 1.0000 - val_loss: 0.0627 - val_accuracy: 1.0000
# Epoch 97/100
# 2/2 [==============================] - 0s 129ms/step - loss: 0.0286 - accuracy: 1.0000 - val_loss: 0.0674 - val_accuracy: 0.9833
# Epoch 98/100
# 2/2 [==============================] - 0s 132ms/step - loss: 0.0225 - accuracy: 1.0000 - val_loss: 0.0878 - val_accuracy: 0.9333
# Epoch 99/100
# 2/2 [==============================] - 0s 135ms/step - loss: 0.0300 - accuracy: 1.0000 - val_loss: 0.0780 - val_accuracy: 0.9667

# %% [markdown]
# ## Evaluation

# %%
def generate_roc(model, ins, outs, ins_validation, outs_validation):
    '''
    Produce a ROC plot given a model, a set of inputs and the true outputs
    
    Assume that model produces N-class output; we will only look at the class 0 scores
    '''
    # Compute probabilistic predictions given images
    pred = model.predict(ins)
    # Compute false positive rate & true positive rate + AUC
    fpr, tpr, thresholds = sklearn.metrics.roc_curve(outs[:,0], pred[:,0])
    auc = sklearn.metrics.auc(fpr, tpr)
    
    # Compute probabilistic predictions given images
    pred_val = model.predict(ins_validation)
    # Compute false positive rate & true positive rate + AUC
    fpr_val, tpr_val, thresholds_val = sklearn.metrics.roc_curve(outs_validation[:,0], pred_val[:,0])
    auc_val = sklearn.metrics.auc(fpr_val, tpr_val)
    
    
    # Generate the plot
    plt.figure(1)
    plt.axis('equal')
    plt.plot([0,1], [0,1], 'k--')
    plt.plot(fpr, tpr, 'b', label='Train AUC = {:.3f}'.format(auc))
    plt.plot(fpr_val, tpr_val, 'r', label='Validation AUC = {:.3f}'.format(auc_val))
    plt.legend(loc='best')
    plt.xlabel('FPR', fontsize=FONTSIZE)
    plt.ylabel('TPR', fontsize=FONTSIZE)

# %%
generate_roc(model, ins, outs, ins_validation, outs_validation)

# %% [markdown]
# ## Visualize Model Internals

# %%
def intermediate_model_state(model, ins, layer_list):
    '''
    Return layer activations for intermediate layers in a model for a set of examples
    
    :param model: Model in question
    :param ins: Input tensor (examples, rows, cols, channels)
    :param layer_list: List of layer names to produce activations for
    :returns: a list of numpy arrays
    '''
    # Translate layer names into corresponding output tensors
    layer_outputs = [l.output for l in model.layers if l.name in layer_list]
    
    # Construct a new Keras model that outputs these tensors
    # The internal structure of the model itself is referenced through the input and output tensor lists
    new_model = keras.models.Model(inputs=model.input, outputs=layer_outputs)
    
    # Evaluate the new model
    activations = new_model.predict(ins_validation)
    
    # Return a list of activation numpy arrays
    return activations

def visualize_state(activations, width=1, example=0, cmap='plasma'):
    '''
    Produce graphical representation of a set of image channels
    
    :param activations: numpy array (example, rows, cols, channels)
    :param width: Number of images displayed horizontally
    :param example: Index of example to display
    :param cmap: Color map to use for plotting
    '''
    # Size of the individual images
    nrows = activations.shape[1]
    ncols = activations.shape[2]
    # Number of channels
    nfilters = activations.shape[3]
    
    # Tile all of the sub-images 
    grid = np.zeros((int((nfilters-1)/width + 1) * nrows, ncols * width))
    
    # Loop over image
    for i in range(nfilters):
        # Compute r,c of tile to place the ith image into
        r = int(i / width)
        c = i % width
        grid[nrows*r: nrows*(r+1), ncols*c:ncols*(c+1)] = activations[example,:,:,i]
        
    # Plot
    plt.matshow(grid, cmap=cmap)

# %%
# Compute activations for 2 layers over a set of examples
layer_list=['C1']
activations = intermediate_model_state(model, ins_validation, layer_list)

# %%
# Plot convolutional layers 1 and 2
example=40
plt.imshow(ins_validation[example,:,:,:])
visualize_state(activations, width=10, example=example)
#visualize_state(activations[0], width=10, example=example)
#visualize_state(activations[1], width=20, example=example)
#visualize_state(activations[2], width=20, example=example)
#visualize_state(activations[3], width=30, example=example)
